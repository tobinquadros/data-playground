# %%
import os
import numpy as np
import pandas as pd
from sodapy import Socrata
import sqlalchemy

# %% [markdown]
# # Connect Postgres

# %%
# Get environment variables from .env & .env.secret files
pg_db = os.getenv('POSTGRES_DB')
pg_hostname = os.getenv('POSTGRES_HOSTNAME')
pg_port = os.getenv('POSTGRES_HOST_PORT')
pg_password = os.getenv('POSTGRES_PASSWORD')
pg_user = os.getenv('POSTGRES_USER')

# Build connection string
conn_str = 'postgresql://{}:{}@{}:{}/{}'.format(pg_user, pg_password, pg_hostname, pg_port, pg_db)

# Uncomment to debug postres connection issues:
# print('Connecting to: {}'.format(conn_str))

# create an `Engine` using the default psycopg2 adapter which uses the Python DBABI spec v2.
engine = sqlalchemy.create_engine(conn_str)

# The engine will ask the connection pool for a connection when the `connect()` or `execute()` methods are called.
conn = engine.connect()

# %% [markdown]
# # Violation Codes

# %% [markdown]
# ## Load The Data

# %%
# Check that the violation_codes postgres table is fully populated.
try:
    result = conn.execute('SELECT count(*) from violation_codes;')
    for row in result:
        if row[0] < 934: # 934 records in .csv
            raise RuntimeWarning('WARNING: violation_codes table not populated correctly!')
        print(row)
except sqlalchemy.exc.SQLAlchemyError as e:
    print('Error fetching data from database! Run `make db-setup` and try again.\n')
    print(e)
# Out:
# (934,)

# %%
# Load the violation codes dataframe into pandas.
violation_codes_df = pd.read_sql(sql='SELECT * from violation_codes;', con=conn)

# %% [markdown]
# ## Basic analysis

# %%
violation_codes_df.shape
# Out:
# (934, 14)

# %%
violation_codes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 934 entries, 0 to 933
# Data columns (total 14 columns):
# violation_id      928 non-null object
# org_id            925 non-null object
# violation_type    925 non-null object
# violation_desc    925 non-null object
# violation_text    912 non-null object
# remedial_text     788 non-null object
# table_name        788 non-null object
# expired_flag      788 non-null object
# date_expired      788 non-null object
# created_by        788 non-null object
# date_created      651 non-null object
# modified_by       651 non-null object
# date_modified     651 non-null object
# fee_setup_id      651 non-null object
# dtypes: object(14)
# memory usage: 102.2+ KB

# %%
violation_codes_df.describe()
# Out:
#        violation_id org_id violation_type violation_desc violation_text  \
# count           928    925            925            925            912
# unique          810      3            789            773            514
# top               -      1           NULL              N           NULL
# freq            119    788            137            137            137
#
#        remedial_text table_name expired_flag date_expired created_by  \
# count            788        788          788          788        788
# unique           211         12            3            3          6
# top             NULL       NULL            N         NULL          2
# freq             443        651          650          786        405
#
#        date_created modified_by date_modified fee_setup_id
# count           651         651           651          651
# unique           42           4            23            1
# top         00:00.0        NULL          NULL         NULL
# freq            397         628           629          651

# %%
def vc_drop_values():
    return violation_codes_df.query('violation_type == "NULL" and violation_desc == "N" and violation_text == "NULL"').index

mask = vc_drop_values()
violation_codes_df.drop(mask, inplace=True)
violation_codes_df.shape
# Out:
# (797, 14)

# %%
def isnumeric(x):
    try:
        int(x)
        return True
    except:
        return False
    
numeric = violation_codes_df['violation_id'].apply(isnumeric)
violation_codes_df['violation_text'][numeric].str.startswith('Section').value_counts()
# Out:
# True     429
# False    346
# Name: violation_text, dtype: int64

# %%
def violation_text_startswith(s):
    if s == None:
        return 'None'
    if s.find('T.C.A') > -1:
        return 'TCA'
    elif s.find('M.C.L') > -1 or s.find('MCL') > -1:
        return 'MCL'
    else:
        return 'Other'
    
violation_codes_df['violation_text_type'] = violation_codes_df['violation_text'].apply(violation_text_startswith)
violation_codes_df.violation_text_type.value_counts()
# Out:
# Other    597
# MCL       98
# TCA       80
# None      22
# Name: violation_text_type, dtype: int64

# %%
violation_codes_df['MCL'] = violation_codes_df['violation_text'][numeric].str.startswith('M.C.L')

# %%
vc_dict = violation_codes_df.violation_type.to_dict()
violation_codes_df.fillna(value=vc_dict)
# Out:
#                                           violation_id org_id violation_type  \
# 0                                                    1      1        BANNERS
# 1                                                    2      1     BGMATOWNER
# 2                                                    4      1      BLDGMAINT
# 3                                                    5      1     BLDGPERMIT
# 4                                                    6      1      BLDGSCOPE
# 5                                                    7      1     BOARDINGRQ
# 6                                                    8      1       BOARDVAC
# 7                                                    9      1         CARROW
# 8                                                   10      1       CERTCOMP
# 9                                                   11      1        CERTOCC
# 10                                                  12      1      CHICKFARM
# 11                                                  13      1     CONSIGSALE
# 12                                                  14      1      CROWDEDFM
# 13                                                  15      1        CROWDGH
# 14                                                  16      1      DUMPDESIG
# 16                                                  17      1       DUMPSTER
# 17                                                  18      1        ECSYSHZ
# 18                                                  19      1     ECSYSHZCRT
# 19                                                  20      1      ELECEAREC
# 20                                                  21      1         ELECEQ
# 21                                                  22      1     ELECEQLIGH
# 22                                                  23      1        ELECFAC
# 23                                                  24      1     ELECSVCPAN
# 24                                                  25      1         EXPARK
# 25                                                  26      1         EXTACC
# 26                                                  27      1       EXTBAHAT
# 27                                                  28      1         EXTBAL
# 28                                                  29      1      EXTCHIMTW
# 29                                                  30      1         EXTDEC
# 30                                                  31      1        EXTDECF
# ..                                                 ...    ...            ...
# 895                                                946      1         BBR14B
# 897                                                947      1          BBR15
# 898                          A.   Department of Health   None           None
# 899                         B.   Fire Marshal Approval   None           None
# 900  C.   Certificate of Registration or Tax Exempt...   None           None
# 901  D.  Letter from charitable organization (only ...   None           None
# 902  E.   Letter of permission to use the Property ...   None           None
# 904                                                948      1          BBR16
# 905                                                949      1          BBR17
# 907                                                951      1          BBR19
# 909                                                952      1          BBR21
# 910                                                953      1          BBR22
# 911                                                954      1          BBR24
# 912                                                955      1          BBR26
# 913  All applications for beer permits must be file...   None           None
# 915                                                956      1          BBR28
# 916                                                957      1          BBR29
# 918                                                959      1          BBR30
# 919  Any business grandfathered under either of the...   None           None
# 921                                                960      1          BBR31
# 922                                                968      1          BBR40
# 924                                                961      1          BBR32
# 925                                                962      1          BBR34
# 927                                                963      1          BBR33
# 928                                                964      1          BBR35
# 929                                                965      1          BBR36
# 930                                                966      1          BBR37
# 931                                                967      1          BBR38
# 932                                                969      1          BBR41
# 933                                                970      1          BBR39
#
#                                violation_desc  \
# 0                                     Banners
# 1              Proper Maintenance Req - Owner
# 2                      Proper Maintenance Req
# 3                    Building Permit Required
# 4                      Scope of Building Code
# 5                       Boarding Requirements
# 6                Boarding of Vacant Buildings
# 7                 Vehicle In The Right-Of-Way
# 8          Certificate of Compliance Required
# 9           Certificate of Occupancy Required
# 10   Chickens and Other Domestic Farm Animals
# 11                           Consignment Sale
# 12            Overcrowding – Unrelated Adults
# 13                  Overcrowding – Group Home
# 14                Dumping in permitted places
# 16    Hours of Collection & Dumpster Required
# 17                  Electrical System Hazards
# 18            Electrical System Certification
# 19                     Electrical Receptacles
# 20                      Electrical Equipment
# 21               Electrical Lighting Fixtures
# 22             Electrical Facilities Required
# 23                   Electrical Service Panel
# 24    Exterior Prop Area – Vehicles – Parking
# 25      Exterior Prop Area – Acces Structures
# 26     Exterior of Bldgs – Basement Hatchways
# 27          Exterior of Buildings - Balconies
# 28    Exterior of Bldgs – Chimneys and Towers
# 29              Exterior of Buildings – Decks
# 30    Exterior of Bldgs – Decorative Features
# ..                                        ...
# 895                          Ascertaining age
# 897                   Special Event Approvals
# 898                                      None
# 899                                      None
# 900                                      None
# 901                                      None
# 902                                      None
# 904                    Payment Types Accepted
# 905                 Crimes of moral turpitude
# 907                              Fire Marshal
# 909                         Surrender permits
# 910               Complaints filed in writing
# 911                       Old or New Location
# 912                Applications 10 days prior
# 913                                      None
# 915       Cannot surrender to avoid penalties
# 916  Cannot temporary permits with complaints
# 918                             Grandfathered
# 919                                      None
# 921                         Expanded premises
# 922                Deny permit after 6 months
# 924                           Caterer Permits
# 925                        Standard penalties
# 927                Past violations considered
# 928                    LLC equals corporation
# 929            No motions for reconsideration
# 930                     Special Event Permits
# 931                          Suspension Rules
# 932          No permit issued with complaints
# 933               Sports Authority Facilities
#
#                                         violation_text         remedial_text  \
# 0    Section 17.32.060 & 17.32.070 -  Banners: Bann...          CAAZ_BANNERS
# 1    Section 16.16.030 (B) - Proper maintenance req...      CAAH_BG_MATOWNER
# 2    Section 16.16.030 (A) - Proper maintenance req...       CAAH_BLDG_MAINT
# 3    Section 16.28.010 - Building Permit Required: ...      CAAB_BLDG_PERMIT
# 4    Section 16.16.020 (B) - The provisions of this...       CAAH_BLDG_SCOPE
# 5    Section 16.24.340 (U) (2) – Boarding of Vacant...    CAAH_BOARDING_REQU
# 6    Section 16.24.340 (U) (1) – Boarding of Vacant...  CAAH_BOARDING_VABLDG
# 7    Section 12.08.210 - Abandoned Vehicles: Abando...       CAMCL_SEW_CONCT
# 8    Section 17.40.580 - Certificate of Compliance:...        CAAZ_CERT_COMP
# 9    Section 16.24.130 – Certificate of Occupancy R...         CAAH_CERT_OCC
# 10   Section 17.16.330 (B) (2)(3) - Domestic Animal...    CAAZ_CHICK_ANIMALS
# 11   Section 17.16.030 ((B) 4) - Consignment Sale (...     CAAZ_CONSIGN_SALE
# 12   Section 16.24.030 & 17.04.060 - Overcrowding: ...      CAAZ_OVCROWDEDFM
# 13   Section 17.04.060 (2) - Family: No more than e...      CAAZ_OVCROWDEDGH
# 14   Section 10.20.130 - Dumping permitted in desig...                  None
# 16   Section 10.20.330 – Dumpsters – Hours of Colle...      CAMCL_LIT_NOTICE
# 17   Section 16.24.490 (C) - Electrical System Haza...      CAAE_ELECSYS_HAZ
# 18   Section 16.24.490 (C) - Electrical System Haza...  CAAE_ELECSYS_HAZCERT
# 19   Section 16.24.500 (B) Receptacles: Every habit...     CAAE_ELECEA_RECPT
# 20   Section 16.24.500 (A) - Electrical Equipment I...          CAAE_ELEC_EQ
# 21   Section 16.24.500 (C) - Lighting Fixtures: Eve...     CAAE_ELECEQ_LIGHT
# 22   Section 16.24.490(A) - Electrical Facilities R...          CAAE_ELECFAC
# 23   Section 16.24.490 (B) - Electrical Service: Se...    CAAE_ELECSVC_PANEL
# 24   Section 16.24.330 (K)(3) – Motor Vehicles (Par...         CAAH_EXT_PARK
# 25   Section 16.24.330 (H) – Accessory Structures: ...          CAAH_EXT_ACC
# 26   Section 16.24.340 (R) – Basement Hatchways: Ba...        CAAH_EXT_BAHAT
# 27   Section 16.24.340 (J) – Balconies: Every exter...        CAAH_EXT_BALCO
# 28   Section 16.24.340 (K) – Chimneys and towers: A...       CAAH_EXT_CHIMTW
# 29   Section 16.24.340 (J) – Decks: Every exterior ...         CAAH_EXT_DECK
# 30   Section 16.24.340 (H) – Decorative Features: A...         CAAH_EXT_DECF
# ..                                                 ...                   ...
# 895  When ascertaining the age of a person purchasi...                  None
# 897  When applying for a special event permit, appl...                  None
# 898                                               None                  None
# 899                                               None                  None
# 900                                               None                  None
# 901                                               None                  None
# 902                                               None                  None
# 904  All application fees for beer permits and beer...                  NULL
# 905  The Metropolitan Beer Permit Board recognizes ...                  None
# 907  Upon making application for an on-sale beer pe...                  None
# 909  Permittees shall surrender their permits, in p...                  NULL
# 910  All complaints requested to be heard by the Me...                  NULL
# 911  An old location is any location that has had a...                  NULL
# 912                                            Rule 26                  None
# 913                                               None                  None
# 915  A permit holder may not avoid a hearing or pro...                  NULL
# 916  Temporary permits shall not be issued by the E...                  None
# 918  1. The grandfather clause of Ordinance 092-246...                  None
# 919                                               None                  None
# 921  No permittee shall expand the premises for whi...                  NULL
# 922  If an application has not been granted or deni...                  None
# 924  Pursuant to Metropolitan Code of Laws Section ...                  NULL
# 925  The following constitutes standard penalties f...                  None
# 927  The beer board shall consider a permit holder'...                  NULL
# 928  For all purposes under the metropolitan beer l...                  NULL
# 929  The Beer Permit Board shall not entertain moti...                  NULL
# 930  Applicants for special event permits will be l...                  NULL
# 931  Upon suspension of a beer permit, the permitte...                  NULL
# 932  A permit shall not be issued by the Executive ...                  NULL
# 933  This rule is applicable only to beer sales wit...                  NULL
#
#     table_name expired_flag date_expired created_by date_created modified_by  \
# 0         NULL            N         NULL          1      03:52.6        NULL
# 1         NULL            N         NULL          1      03:52.6        NULL
# 2         NULL            N         NULL          1      03:52.6        NULL
# 3         NULL            N         NULL          1      03:52.6        NULL
# 4         NULL            N         NULL          1      03:52.6        NULL
# 5         NULL            N         NULL          1      03:52.6        NULL
# 6         NULL            N         NULL          1      03:52.6        NULL
# 7         NULL            N         NULL          1      03:52.6        NULL
# 8         NULL            N         NULL          1      03:52.6        NULL
# 9         NULL            N         NULL          1      03:52.6        NULL
# 10        NULL            N         NULL          1      03:52.6        NULL
# 11        NULL            N         NULL          1      03:52.6        NULL
# 12        NULL            N         NULL          1      03:52.6        NULL
# 13        NULL            N         NULL          1      03:52.6        NULL
# 14        None         None         None       None         None        None
# 16        NULL            N         NULL          1      03:52.6        NULL
# 17        NULL            N         NULL          1      03:52.6        NULL
# 18        NULL            N         NULL          1      03:52.6        NULL
# 19        NULL            N         NULL          1      03:52.6        NULL
# 20        NULL            N         NULL          1      03:52.6        NULL
# 21        NULL            N         NULL          1      03:52.6        NULL
# 22        NULL            N         NULL          1      03:52.6        NULL
# 23        NULL            N         NULL          1      03:52.6        NULL
# 24        NULL            N         NULL          1      03:52.6        NULL
# 25        NULL            N         NULL          1      03:52.6        NULL
# 26        NULL            N         NULL          1      03:52.6        NULL
# 27        NULL            N         NULL          1      03:52.6        NULL
# 28        NULL            N         NULL          1      03:52.6        NULL
# 29        NULL            N         NULL          1      03:52.6        NULL
# 30        NULL            N         NULL          1      03:52.6        NULL
# ..         ...          ...          ...        ...          ...         ...
# 895       None         None         None       None         None        None
# 897       None         None         None       None         None        None
# 898       None         None         None       None         None        None
# 899       None         None         None       None         None        None
# 900       None         None         None       None         None        None
# 901       None         None         None       None         None        None
# 902       None         None         None       None         None        None
# 904       NULL            N         NULL      10635      01:37.1        NULL
# 905       None         None         None       None         None        None
# 907       None         None         None       None         None        None
# 909       NULL            N         NULL      10635      04:56.4        NULL
# 910       NULL            N         NULL      10635      05:39.8        NULL
# 911       NULL            N         NULL      10635      06:28.6        NULL
# 912       None         None         None       None         None        None
# 913       None         None         None       None         None        None
# 915       NULL            N         NULL      10635      29:30.8        NULL
# 916       None         None         None       None         None        None
# 918       None         None         None       None         None        None
# 919       None         None         None       None         None        None
# 921       NULL            N         NULL      10635      38:33.5        NULL
# 922       None         None         None       None         None        None
# 924       NULL            N         NULL      10635      56:24.9        NULL
# 925       None         None         None       None         None        None
# 927       NULL            N         NULL      10635      59:48.6        NULL
# 928       NULL            N         NULL      10635      03:34.8        NULL
# 929       NULL            N         NULL      10635      04:56.0        NULL
# 930       NULL            N         NULL      10635      08:59.4        NULL
# 931       NULL            N         NULL      10635      10:16.9        NULL
# 932       NULL            N         NULL      10635      12:53.1        NULL
# 933       NULL            N         NULL      10635      16:46.8        NULL
#
#     date_modified fee_setup_id violation_text_type    MCL
# 0            NULL         NULL               Other  False
# 1            NULL         NULL               Other  False
# 2            NULL         NULL               Other  False
# 3            NULL         NULL               Other  False
# 4            NULL         NULL               Other  False
# 5            NULL         NULL               Other  False
# 6            NULL         NULL               Other  False
# 7            NULL         NULL               Other  False
# 8            NULL         NULL               Other  False
# 9            NULL         NULL               Other  False
# 10           NULL         NULL               Other  False
# 11           NULL         NULL               Other  False
# 12           NULL         NULL               Other  False
# 13           NULL         NULL               Other  False
# 14           None         None               Other  False
# 16           NULL         NULL               Other  False
# 17           NULL         NULL               Other  False
# 18           NULL         NULL               Other  False
# 19           NULL         NULL               Other  False
# 20           NULL         NULL               Other  False
# 21           NULL         NULL               Other  False
# 22           NULL         NULL               Other  False
# 23           NULL         NULL               Other  False
# 24           NULL         NULL               Other  False
# 25           NULL         NULL               Other  False
# 26           NULL         NULL               Other  False
# 27           NULL         NULL               Other  False
# 28           NULL         NULL               Other  False
# 29           NULL         NULL               Other  False
# 30           NULL         NULL               Other  False
# ..            ...          ...                 ...    ...
# 895          None         None               Other  False
# 897          None         None               Other  False
# 898          None         None                None    NaN
# 899          None         None                None    NaN
# 900          None         None                None    NaN
# 901          None         None                None    NaN
# 902          None         None                None    NaN
# 904          NULL         NULL               Other  False
# 905          None         None               Other  False
# 907          None         None               Other  False
# 909          NULL         NULL               Other  False
# 910          NULL         NULL               Other  False
# 911          NULL         NULL               Other  False
# 912          None         None               Other  False
# 913          None         None                None    NaN
# 915          NULL         NULL               Other  False
# 916          None         None               Other  False
# 918          None         None               Other  False
# 919          None         None                None    NaN
# 921          NULL         NULL               Other  False
# 922          None         None               Other  False
# 924          NULL         NULL               Other  False
# 925          None         None               Other  False
# 927          NULL         NULL               Other  False
# 928          NULL         NULL               Other  False
# 929          NULL         NULL                 TCA  False
# 930          NULL         NULL                 TCA  False
# 931          NULL         NULL               Other  False
# 932          NULL         NULL               Other  False
# 933          NULL         NULL               Other  False
#
# [797 rows x 16 columns]

# %% [markdown]
# # Property Standards Violations Data

# %% [markdown]
# ## Helpers

# %%
def get_property_standards_violations_update(save=False):
    """
        Socrata client pulls updated data from https://data.nashville.gov
        
        Property Standards Violations data docs: https://dev.socrata.com/foundry/data.nashville.gov/tcjq-k4c5
        
        Socrata client docs: https://dev.socrata.com/foundry/data.nashville.gov/tcjq-k4c5
        
        Dataframe will be saved to .csv file if save=True is passed as argument.
    """
    
    socrata_app_token = os.getenv('SOCRATA_APP_TOKEN')
    client = Socrata("data.nashville.gov", socrata_app_token)
    results = client.get("tcjq-k4c5", limit=100000) # dataset has > 51,000 records
    psv_df = pd.DataFrame.from_records(results)
    
    # clean df
    for column in psv_df.columns:
        if column.startswith(':@'):
            psv_df.drop(column, axis=1, inplace=True)
    
    # optionally save to .csv
    if save == True:
        save_update_to_csv(psv_df, 'property-standards-violations')
    
    return psv_df

def save_update_to_csv(df, name):
    filename = './data/{}-update.csv'.format(name)
    df.to_csv(filename, index=False)

# %% [markdown]
# Optionally get an update of the data (the shape can be diffed with the current df):

# %%
# get_property_standards_violations_update(save=True).shape

# %% [markdown]
# # Load The Data

# %%
# Check that the property_standards_violations postgres table is fully populated.
try:
    result = conn.execute('SELECT count(*) from property_standards_violations;')
    for row in result:
        if row[0] < 51696: # records in original .csv
            raise RuntimeWarning('WARNING: property_standards_violations table not populated correctly!')
        print(row)
except sqlalchemy.exc.SQLAlchemyError as e:
    print('Error fetching data from database! Run `make db-setup` and try again.\n')
    print(e)
# Out:
# (51696,)

# %%
# Load the property standards violations dataframe into pandas.
psv_df = pd.read_sql(sql='SELECT * from property_standards_violations;', con=conn)

# %% [markdown]
# ## Basic analysis

# %%
psv_df.shape
# Out:
# (51696, 21)

# %%
psv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51696 entries, 0 to 51695
# Data columns (total 21 columns):
# city                       51077 non-null object
# complaint_source           51602 non-null object
# council_district           51159 non-null object
# date_received              51696 non-null object
# last_activity              51332 non-null object
# last_activity_date         51332 non-null object
# last_activity_result       51320 non-null object
# mapped_location            50626 non-null object
# mapped_location_address    51317 non-null object
# mapped_location_city       51077 non-null object
# mapped_location_state      51127 non-null object
# mapped_location_zip        51272 non-null object
# property_address           51317 non-null object
# property_apn               51260 non-null object
# property_owner             51696 non-null object
# reported_problem           50990 non-null object
# request                    51696 non-null object
# state                      51127 non-null object
# status                     51696 non-null object
# violations_noted           35808 non-null object
# zip                        51272 non-null object
# dtypes: object(21)
# memory usage: 8.3+ MB

# %%
psv_df['council_district']
# Out:
# 0         3
# 1        29
# 2        11
# 3        11
# 4        26
# 5        17
# 6        16
# 7         9
# 8        20
# 9        11
# 10       13
# 11       11
# 12       27
# 13       29
# 14       16
# 15       22
# 16       18
# 17       21
# 18       16
# 19       11
# 20       16
# 21       16
# 22       16
# 23       11
# 24       30
# 25       21
# 26       21
# 27       13
# 28       29
# 29       13
#          ..
# 51666    17
# 51667    13
# 51668    11
# 51669     6
# 51670     4
# 51671    31
# 51672    28
# 51673    14
# 51674    16
# 51675    12
# 51676    11
# 51677    12
# 51678    12
# 51679    35
# 51680    30
# 51681     8
# 51682    16
# 51683    11
# 51684    22
# 51685     5
# 51686    24
# 51687    24
# 51688    26
# 51689    15
# 51690    15
# 51691    28
# 51692    15
# 51693    24
# 51694     6
# 51695    11
# Name: council_district, Length: 51696, dtype: object
